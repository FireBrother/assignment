# %%
import pandas as pd
import logging
import matplotlib.pyplot as plt
import seaborn as sns

from utils import *
from simulator import Simulator

# %%
sim = Simulator()
sim.logger.setLevel(logging.DEBUG)

# %%
fundamentals = pd.read_hdf('jqstorage.h5', 'fundamentals')

# %% [markdown]
# ##  特征扩展

# %%
import featuretools as ft

# %%
es = ft.EntitySet(id='fundamentals')

# %%
columns = fundamentals.columns
columns = set(columns.tolist())
columns.remove('date')
columns.remove('code')
columns = list(columns)

# %%
es = es.entbity_from_dataframe(entity_id='fundamentals', dataframe = fundamentals[columns], make_index=True, index='index')

# %%
features, feature_names = ft.dfs(entityset = es, target_entity = 'fundamentals', 
                                 agg_primitives = [], trans_primitives = [Divide, Subtract], max_depth=2)
feature_names
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-a59bc35f91ee> in <module>()
#       1 features, feature_names = ft.dfs(entityset = es, target_entity = 'fundamentals',
# ----> 2                                  agg_primitives = [], trans_primitives = [Divide, Subtract], max_depth=2)
#       3 feature_names
#
# /usr/local/lib/python3.6/site-packages/featuretools/synthesis/dfs.py in dfs(entities, relationships, entityset, target_entity, cutoff_time, instance_ids, agg_primitives, trans_primitives, allowed_paths, max_depth, ignore_entities, ignore_variables, seed_features, drop_contains, drop_exact, where_primitives, max_features, cutoff_time_in_index, save_progress, features_only, training_window, approximate, chunk_size, verbose)
#     165                                       seed_features=seed_features)
#     166
# --> 167     features = dfs_object.build_features(verbose=verbose)
#     168
#     169     if features_only:
#
# /usr/local/lib/python3.6/site-packages/featuretools/synthesis/deep_feature_synthesis.py in build_features(self, variable_types, verbose)
#     290         # sanity check for duplicate features
#     291         l = [f.hash() for f in new_features]
# --> 292         assert len(set([f for f in l if l.count(f) > 1])) == 0, \
#     293             'Multiple features with same name' + \
#     294             str(set([f for f in l if l.count(f) > 1]))
#
# /usr/local/lib/python3.6/site-packages/featuretools/synthesis/deep_feature_synthesis.py in <listcomp>(.0)
#     290         # sanity check for duplicate features
#     291         l = [f.hash() for f in new_features]
# --> 292         assert len(set([f for f in l if l.count(f) > 1])) == 0, \
#     293             'Multiple features with same name' + \
#     294             str(set([f for f in l if l.count(f) > 1]))
#
# KeyboardInterrupt:

# %%
from featuretools.primitives import make_agg_primitive, make_trans_primitive
from featuretools.variable_types import Numeric

def divide(a, b):
    return a / b

def subtract(a, b):
    return a - b

Divide = make_trans_primitive(function=divide, input_types=[Numeric, Numeric], return_type=Numeric)
Subtract = make_trans_primitive(function=subtract, input_types=[Numeric, Numeric], return_type=Numeric)

# %% [markdown]
# ## 单因子测试

# %%
factor = 'basic_eps'
sim.reset()
sim.logger.setLevel(logging.INFO)
history_asset = defaultdict(list)

points = [x[0] for x in get_sample_point()[30:]]

for part in range(1, 6):
    sim.reset()
    for date in points:
        sim.date = date
        df = fundamentals[fundamentals.date==date][['code', factor]]
        df = df.sort_values(factor, ascending=False)
        securities = df['code'][df.shape[0]//5*(part-1):df.shape[0]//5*part]

        for security in sim.stock:
            if sim.stock[security] > 0:
                sim.order_target(security, 0)
        asset = sim.cash
        for security in securities.values:
            sim.order_value(security, asset/len(securities.values))
        history_asset[part].append(sim.get_asset())

# %%
# %matplotlib inline
plt.figure(figsize=(10,5))
plt.title('{}'.format(factor))
for part in history_asset:
    plt.plot(points[:len(history_asset[part])], history_asset[part])
plt.legend(history_asset.keys())
# Out:
# Text(0.5,1,'basic_eps')

# %%
points
# Out:
# [(datetime.datetime(2015, 7, 22, 0, 0), 250),
#  (datetime.datetime(2015, 9, 9, 0, 0), 250),
#  (datetime.datetime(2015, 9, 9, 0, 0), 250),
#  (datetime.datetime(2015, 11, 12, 0, 0), 250),
#  (datetime.datetime(2015, 11, 12, 0, 0), 250),
#  (datetime.datetime(2015, 12, 7, 0, 0), 256),
#  (datetime.datetime(2016, 1, 7, 0, 0), 263),
#  (datetime.datetime(2016, 2, 15, 0, 0), 261),
#  (datetime.datetime(2016, 3, 7, 0, 0), 258),
#  (datetime.datetime(2016, 4, 7, 0, 0), 256),
#  (datetime.datetime(2016, 5, 9, 0, 0), 261),
#  (datetime.datetime(2016, 6, 7, 0, 0), 272),
#  (datetime.datetime(2016, 7, 7, 0, 0), 271),
#  (datetime.datetime(2016, 8, 8, 0, 0), 272),
#  (datetime.datetime(2016, 9, 7, 0, 0), 272),
#  (datetime.datetime(2016, 10, 10, 0, 0), 266),
#  (datetime.datetime(2016, 11, 7, 0, 0), 275),
#  (datetime.datetime(2016, 12, 7, 0, 0), 278),
#  (datetime.datetime(2017, 1, 9, 0, 0), 286),
#  (datetime.datetime(2017, 2, 7, 0, 0), 286),
#  (datetime.datetime(2017, 3, 7, 0, 0), 286),
#  (datetime.datetime(2017, 4, 7, 0, 0), 288),
#  (datetime.datetime(2017, 5, 8, 0, 0), 286),
#  (datetime.datetime(2017, 6, 7, 0, 0), 282),
#  (datetime.datetime(2017, 7, 7, 0, 0), 284),
#  (datetime.datetime(2017, 8, 7, 0, 0), 286),
#  (datetime.datetime(2017, 9, 7, 0, 0), 287),
#  (datetime.datetime(2017, 10, 9, 0, 0), 287),
#  (datetime.datetime(2017, 11, 7, 0, 0), 288),
#  (datetime.datetime(2017, 12, 7, 0, 0), 289)]
